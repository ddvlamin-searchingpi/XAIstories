# %%
import pandas as pd
import numpy as np
from scipy.stats import kendalltau


from stories.llm_wrappers import OllamaWrapper
from stories.prompts import make_rank_evaluation_prompt

# %%
with open("evaluation_prompt_0.txt", "r") as fin:
    prompt = fin.read()

# %%
llm = OllamaWrapper("llama3.1-greedy:latest", temperature=0.0)

# %%
response = llm.generate_json_response(prompt)
response
# Out:
# {'0': 'Goal Scored',
#  '1': 'Pass Accuracy %',
#  '2': 'Ball Possession %',
#  '3': 'Distance Covered (Kms)',
#  '4': 'Free Kicks',
#  '5': 'Corners',
#  '6': 'Blocked shots'}

# %%
explanations_df = pd.read_csv("explanations.csv").set_index("story_id")

# %%
true_rank = explanations_df.loc[0].sort_values(by="Shap value", key=lambda s: s.abs(), ascending=False)
true_rank["rank"] = range(len(true_rank))
true_rank.reset_index(drop=True, inplace=True)
true_rank.set_index("Feature name", inplace=True)
true_rank
# Out:
#                         Feature value  Shap value  Model coefficient  \
# Feature name
# Goal Scored                         2    1.369433           2.603175
# Offsides                            0   -1.008332           0.969639
# Ball Possession %                  59   -0.350419          -0.366783
# Pass Accuracy %                    89    0.307003           0.305696
# Distance Covered (Kms)             97    0.260371          -0.323417
# Free Kicks                         24    0.240641           0.112049
# Corners                             5    0.234285           1.307775
# Blocked                             2    0.220169          -0.333510
#
#                         Average feature value  \
# Feature name
# Goal Scored                          1.384615
# Offsides                             1.192308
# Ball Possession %                   49.538462
# Pass Accuracy %                     83.384615
# Distance Covered (Kms)             106.615385
# Free Kicks                          13.884615
# Corners                              4.576923
# Blocked                              3.538462
#
#                                                       Feature description  \
# Feature name
# Goal Scored             Number of goals scored by the team during the ...
# Offsides                      Number of times the team was caught offside
# Ball Possession %       Percentage of ball possession by the team duri...
# Pass Accuracy %         Percentage of passes that successfully reached...
# Distance Covered (Kms)  Total distance covered by the team's players d...
# Free Kicks                         Number of free kicks taken by the team
# Corners                          Number of corner kicks taken by the team
# Blocked                 Number of shots that were blocked by the opponent
#
#                         rank
# Feature name
# Goal Scored                0
# Offsides                   1
# Ball Possession %          2
# Pass Accuracy %            3
# Distance Covered (Kms)     4
# Free Kicks                 5
# Corners                    6
# Blocked                    7

# %%
true_rank
# Out:
#                     Feature name  Feature value  Shap value  \
# story_id
# 0                    Goal Scored              2    1.369433
# 0                       Offsides              0   -1.008332
# 0              Ball Possession %             59   -0.350419
# 0                Pass Accuracy %             89    0.307003
# 0         Distance Covered (Kms)             97    0.260371
# 0                     Free Kicks             24    0.240641
# 0                        Corners              5    0.234285
# 0                        Blocked              2    0.220169
#
#           Model coefficient  Average feature value  \
# story_id
# 0                  2.603175               1.384615
# 0                  0.969639               1.192308
# 0                 -0.366783              49.538462
# 0                  0.305696              83.384615
# 0                 -0.323417             106.615385
# 0                  0.112049              13.884615
# 0                  1.307775               4.576923
# 0                 -0.333510               3.538462
#
#                                         Feature description  rank
# story_id
# 0         Number of goals scored by the team during the ...     0
# 0               Number of times the team was caught offside     1
# 0         Percentage of ball possession by the team duri...     2
# 0         Percentage of passes that successfully reached...     3
# 0         Total distance covered by the team's players d...     4
# 0                    Number of free kicks taken by the team     5
# 0                  Number of corner kicks taken by the team     6
# 0         Number of shots that were blocked by the opponent     7

# %%
matches = 0
for rank, feature_name in response.items():
    try:
        matches += 1 if true_rank.loc[feature_name]["rank"] == int(rank) else 0
    except KeyError:
        continue

# %%
print(f"rank metric: {matches/len(response)}, {matches}, {len(response)}")
# Out:
# rank metric: 0.2857142857142857, 2, 7

# %%
sorted_feature_names = [feature_name for _, feature_name in sorted(response.items(), key=lambda x: int(x[0])) if feature_name in set(true_rank["Feature name"].values)]
true_= [feature_name for feature_name in true_rank["Feature name"].values if feature_name in set(sorted_feature_names)]

# %%
tau, p = kendalltau(
    true_rank.loc[sorted_feature_names]["rank"].values, 
    true_rank.loc[true_]["rank"].values
)
print(tau, p)
# Out:
# 0.8666666666666666 0.016666666666666666
